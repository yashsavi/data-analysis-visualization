# %%
import pandas as pd
import numpy as np

# %%
dict1=({
    'name':["yash","jai",'priya','surbhi','parkash','deepu','jaya'],
    'age':[20,22,24,25,27,26,np.nan],
    'marks':[80,82,76,87,98,67,90],
    'gender':['m','m','f','f','m','m','f']
})

df=pd.DataFrame(dict1)
df
# Out:
#       name   age  marks gender
# 0     yash  20.0     80      m
# 1      jai  22.0     82      m
# 2    priya  24.0     76      f
# 3   surbhi  25.0     87      f
# 4  parkash  27.0     98      m
# 5    deepu  26.0     67      m
# 6     jaya   NaN     90      f

# %%
df.head(3)
# Out:
#     name   age  marks gender
# 0   yash  20.0     80      m
# 1    jai  22.0     82      m
# 2  priya  24.0     76      f

# %%
df.tail(3)
# Out:
#       name   age  marks gender
# 4  parkash  27.0     98      m
# 5    deepu  26.0     67      m
# 6     jaya   NaN     90      f

# %%
print("total number of rows is:-",df.shape[0])
print("total number of columns is:-",df.shape[1])
# Out:
# total number of rows is:- 7
# total number of columns is:- 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   age     6 non-null      float64
#  2   marks   7 non-null      int64
#  3   gender  7 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 352.0+ bytes

# %%
df.isnull().sum()
# Out:
# name      0
# age       1
# marks     0
# gender    0
# dtype: int64

# %%
df.describe()
# Out:
#              age      marks
# count   6.000000   7.000000
# mean   24.000000  82.857143
# std     2.607681  10.040395
# min    20.000000  67.000000
# 25%    22.500000  78.000000
# 50%    24.500000  82.000000
# 75%    25.750000  88.500000
# max    27.000000  98.000000

# %%
df['gender'].nunique()
# Out:
# 2

# %%
df['gender'].value_counts()[0]
# Out:
# 4

# %%
df
# Out:
#       name   age  marks gender
# 0     yash  20.0     80      m
# 1      jai  22.0     82      m
# 2    priya  24.0     76      f
# 3   surbhi  25.0     87      f
# 4  parkash  27.0     98      m
# 5    deepu  26.0     67      m
# 6     jaya   NaN     90      f

# %%
df[(df['marks']>=85) & (df['marks']<=100)]
# Out:
#       name   age  marks gender
# 3   surbhi  25.0     87      f
# 4  parkash  27.0     98      m
# 6     jaya   NaN     90      f

# %%
len(df[df['marks'].between(85,100)])
# Out:
# 3

# %%
df["marks"].mean()
# Out:
# 82.85714285714286

# %%
def marks_filter(a):
    return a/2

# %%
df['half_marks']=df['marks'].apply(marks_filter)

# %%
df
# Out:
#       name   age  marks gender  half_marks
# 0     yash  20.0     80      m        40.0
# 1      jai  22.0     82      m        41.0
# 2    priya  24.0     76      f        38.0
# 3   surbhi  25.0     87      f        43.5
# 4  parkash  27.0     98      m        49.0
# 5    deepu  26.0     67      m        33.5
# 6     jaya   NaN     90      f        45.0

# %%
df['half_marks']=df['half_marks'].astype(int)
df
# Out:
#       name   age  marks gender  half_marks
# 0     yash  20.0     80      m          40
# 1      jai  22.0     82      m          41
# 2    priya  24.0     76      f          38
# 3   surbhi  25.0     87      f          43
# 4  parkash  27.0     98      m          49
# 5    deepu  26.0     67      m          33
# 6     jaya   NaN     90      f          45

# %%
#lambda function
df["marks"].apply(lambda x:x//2)
# Out:
# 0    40
# 1    41
# 2    38
# 3    43
# 4    49
# 5    33
# 6    45
# Name: marks, dtype: int64

# %%
df['name'].apply(len)
# Out:
# 0    4
# 1    3
# 2    5
# 3    6
# 4    7
# 5    5
# 6    4
# Name: name, dtype: int64

# %%
df
# Out:
#       name   age  marks gender  half_marks
# 0     yash  20.0     80      m          40
# 1      jai  22.0     82      m          41
# 2    priya  24.0     76      f          38
# 3   surbhi  25.0     87      f          43
# 4  parkash  27.0     98      m          49
# 5    deepu  26.0     67      m          33
# 6     jaya   NaN     90      f          45

# %%
#map function
df['male_female_encoded']=df['gender'].map({'m':1,'f':0})

# %%
df
# Out:
#       name   age  marks gender  half_marks  male_female_encoded
# 0     yash  20.0     80      m          40                    1
# 1      jai  22.0     82      m          41                    1
# 2    priya  24.0     76      f          38                    0
# 3   surbhi  25.0     87      f          43                    0
# 4  parkash  27.0     98      m          49                    1
# 5    deepu  26.0     67      m          33                    1
# 6     jaya   NaN     90      f          45                    0

# %%
df.drop(['male_female_encoded','half_marks'],axis=1,inplace=True)

# %%
df
# Out:
#       name   age  marks gender
# 0     yash  20.0     80      m
# 1      jai  22.0     82      m
# 2    priya  24.0     76      f
# 3   surbhi  25.0     87      f
# 4  parkash  27.0     98      m
# 5    deepu  26.0     67      m
# 6     jaya   NaN     90      f

# %%
df.columns
# Out:
# Index(['name', 'age', 'marks', 'gender'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.sort_values(by=["marks",'gender'],ascending=False)
# Out:
#       name   age  marks gender
# 4  parkash  27.0     98      m
# 6     jaya   NaN     90      f
# 3   surbhi  25.0     87      f
# 1      jai  22.0     82      m
# 0     yash  20.0     80      m
# 2    priya  24.0     76      f
# 5    deepu  26.0     67      m

# %%
df
# Out:
#       name   age  marks gender
# 0     yash  20.0     80      m
# 1      jai  22.0     82      m
# 2    priya  24.0     76      f
# 3   surbhi  25.0     87      f
# 4  parkash  27.0     98      m
# 5    deepu  26.0     67      m
# 6     jaya   NaN     90      f

# %%
df[(df['gender']=='f')][['name','marks']]
# Out:
#      name  marks
# 2   priya     76
# 3  surbhi     87
# 6    jaya     90

# %%
df[df['gender'].isin(['f'])][["name",'marks']] #second method
# Out:
#      name  marks
# 2   priya     76
# 3  surbhi     87
# 6    jaya     90

# %% [markdown]
# # case studies 2 start here

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",14)

# %%
df1=pd.read_csv("Ecommerce Purchases")
df1.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df1.shape
# Out:
# (10000, 14)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df1.isnull().sum()/len(df1)
# Out:
# Address             0.0
# Lot                 0.0
# AM or PM            0.0
# Browser Info        0.0
# Company             0.0
# Credit Card         0.0
# CC Exp Date         0.0
# CC Security Code    0.0
# CC Provider         0.0
# Email               0.0
# Job                 0.0
# IP Address          0.0
# Language            0.0
# Purchase Price      0.0
# dtype: float64

# %%
df1.shape
# Out:
# (10000, 14)

# %%
print("Total Rows in the dataset are:- ",df1.shape[0])
print("Total columns in the dataset are:- ",df1.shape[1])
# Out:
# Total Rows in the dataset are:-  10000
# Total columns in the dataset are:-  14

# %%
df1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#6. Highest and Lowest Purchase Prices.
print(df1['Purchase Price'].max())
print(df1['Purchase Price'].min())
# Out:
# 99.99
# 0.0

# %%
#7. Average Purchase Price
df1['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
df1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
#8. How many people have French 'fr' as their Language?
french_filter=df1[df1['Language']=='fr']
len(french_filter)
# Out:
# 1097

# %%
#9. Job Title Contains Engineer
df1[df1["Job"].str.contains('engineer',case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# 64    937 Weaver Isle Apt. 096\nTracyborough, KY 182...  97 QO       AM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# 92                Unit 9659 Box 0618\nDPO AA 00377-5360  37 jN       AM
# 98    192 Malone Stream Suite 756\nLake Gary, KS 373...  00 zU       AM
# 103                480 Ronald Cape\nJohnville, MA 53644  11 wg       AM
# 155             649 Murphy Estates\nWayneland, MS 16599  18 ou       PM
# 173   8071 Ellis Courts Suite 037\nNew Katelynville,...  12 VI       PM
# ...

# %%
df1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df1['CC Provider'].uniqueque()
# Out:
# array(['JCB 16 digit', 'Mastercard', 'Discover',
#        'Diners Club / Carte Blanche', 'VISA 16 digit', 'VISA 13 digit',
#        'American Express', 'Voyager', 'JCB 15 digit', 'Maestro'],
#       dtype=object)

# %%
#10. Find The Email of the person with the following IP Address: 132.207.160.22
df1[df1['IP Address']=='132.207.160.22'][['Email']]
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
#11. How many People have Mastercard as their Credit Card Provider and made a purchase above 50?
len(df1[(df1['CC Provider']=='Mastercard') & (df1['Purchase Price']>50)])
# Out:
# 405

# %%
#12. Find the email of the person with the following Credit Card Number: 4664825258997302
df1[df1['Credit Card'] == 4664825258997302][['Email']]
# Out:
#                   Email
# 9992  bberry@wright.net

# %%
#13. How many people purchase during the AM and how many people purchase during PM?
print(df1['AM or PM'].value_counts())
df1['AM or PM'].value_counts().plot(kind='bar')
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64
# <AxesSubplot:>

# %%
df1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df1['CC Exp Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10000 entries, 0 to 9999
# Series name: CC Exp Date
# Non-Null Count  Dtype
# --------------  -----
# 10000 non-null  object
# dtypes: object(1)
# memory usage: 78.2+ KB

# %%
#14. How many people have a credit card that expires in 2020?
df1['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
# 5       07/25
# 6       07/24
# 7       06/25
# 8       04/24
# 9       01/17
# 10      02/17
# 11      06/26
# 12      05/26
# 13      01/25
# 14      09/22
# 15      04/25
# 16      06/22
# 17      01/26
# 18      12/22
# 19      02/20
# 20      03/22
# 21      03/25
# 22      07/22
# 23      02/23
# 24      07/18
# 25      05/19
# 26      03/19
# 27      12/16
# 28      11/24
# 29      07/22
# 30      04/17
# 31      03/22
# 32      01/20
# 33      05/25
# 34      01/21
# 35      09/16
# 36      09/20
# 37      06/18
# 38      12/20
# 39      02/19
# 40      05/26
# 41      08/20
# 42      12/20
# 43      04/23
# 44      08/24
# 45      03/26
# 46      08/20
# 47      09/20
# 48      05/24
# 49      05/25
# 50      05/19
# 51      10/17
# 52      05/26
# 53      08/17
# 54      11/23
# 55      09/19
# 56      02/26
# 57      01/24
# 58      06/18
# 59      10/20
# 60      05/20
# 61      01/17
# ...

# %%
def expire_filter():
    count=0
    for date in df1['CC Exp Date']:
        if date.split('/')[1]=='20':
                 count=count+1
    print(count)
    
expire_filter()
# Out:
# 988

# %%
df1[df1['CC Exp Date'].apply(lambda x:x[3:]=='20')]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 32                     Unit 3628 Box 6778\nDPO AE 72362  39 Qm       PM
# 36    9374 Skinner Common Apt. 254\nChristopherfort,...  80 Fq       PM
# 38    9671 Riley Drives Apt. 746\nPort Davidtown, TN...  15 vj       AM
# 41    779 Sydney Keys Apt. 119\nAnthonyside, NH 2179...  21 lh       PM
# 42        605 Dillon Parks Apt. 900\nSarafort, WV 87894  40 cz       AM
# 46            1663 Michael Course\nPort Susan, MA 25996  23 Xz       AM
# 47    261 Walton Road Suite 704\nMaldonadoshire, MD ...  55 DV       PM
# 59    0585 Lucas Gateway Suite 198\nBrandyville, WI ...  14 On       PM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# 67       25598 Ashley Square\nRobertstad, SD 20936-0349  35 LT       PM
# ...

# %%
df1.head(1)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
#
#                                         Browser Info          Company  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  Martinez-Herman
#
#         Credit Card CC Exp Date  CC Security Code   CC Provider  \
# 0  6011929061123406       02/20               900  JCB 16 digit
#
#                Email                                     Job       IP Address  \
# 0  pdunlap@yahoo.com  Scientist, product/process development  149.146.147.205
#
#   Language  Purchase Price
# 0       el           98.14

# %%
#15. What are the top 5 most popular email providers (e.g. gmail.com, yahoo.com, etc...) 
df1['Email'].apply(lambda x:x.split('@')[1]).value_counts().sort_values(ascending=False).head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64
